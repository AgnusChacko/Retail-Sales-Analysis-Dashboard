# %% [markdown]
# # Retail Sales Data Analysis

# %% [markdown]
# ## Objective
# Analyze retail sales data to identify trends and generate business insights.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv("C:/Users/agnes/Downloads/superstore.csv")

df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
# ...

# %% [markdown]
# ## Understanding the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
df["Order.Date"] = pd.to_datetime(df["Order.Date"])
df["Ship.Date"] = pd.to_datetime(df["Ship.Date"])

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# 记录数               0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
df["Month"] = df["Order.Date"].dt.month

# %%
total_sales = df["Sales"].sum()
print(total_sales)
# Out:
# 12642905

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Sales by Category

# %%
category_sales = df.groupby("Category")["Sales"].sum()

category_sales.plot(kind="bar")
plt.title("Sales by Category")
plt.show()

# %% [markdown]
# **Insight:** Technology category has highest sales.

# %% [markdown]
# ### Sales by Region

# %%
region_sales = df.groupby("Region")["Sales"].sum()

region_sales.plot(kind="pie", autopct="%1.1f%%")
plt.title("Sales by Region")
plt.show()

# %% [markdown]
# **Insight:** Sales distribution is uneven across regions, with one region contributing the largest share (around 22%), while others like EMEA and Central Asia show lower contributions, highlighting potential areas for market expansion.

# %% [markdown]
# ### Top Products Analysis

# %%
top_products = df.groupby("Product.Name")["Sales"].sum().sort_values(ascending=False).head(10)

top_products.plot(kind="barh")
plt.title("Top 10 Products")
plt.show()

# %% [markdown]
# **Insight:** Sales are highly concentrated among a few top-performing products, with Cisco and Motorola smartphones leading revenue generation, indicating potential risk and opportunity for product diversification.

# %% [markdown]
# ### Monthly Sales Trend

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()

monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.show()

# %% [markdown]
# **Insight:** Sales demonstrate an upward trend across the year with mid-year volatility, followed by strong year-end growth, indicating seasonal demand patterns and improved performance in later months.

# %%
df.to_csv("clean_superstore.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\agnes'

# %%
df.to_csv("clean_superstore.csv", index=False)

# %% [markdown]
# ## Conclusion
#
# - Sales show an overall increasing trend with strong performance in later months.
# - A few top products contribute significantly to total revenue.
# - Sales distribution varies across regions, with some regions outperforming others.
# - Business can improve performance by focusing on low-performing regions and diversifying product offerings.

# %% [markdown]
# ## Business Recommendations
#
# - Focus marketing efforts on top-performing products to maximize revenue.
# - Improve strategies in low-performing regions to increase sales.
# - Maintain inventory for high-demand products.
# - Analyze seasonal trends to plan future sales strategies.
